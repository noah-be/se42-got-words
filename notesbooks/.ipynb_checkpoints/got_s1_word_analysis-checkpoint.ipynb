# %%
import json
from pathlib import Path

path = Path("../data/raw/season1.json")
raw = path.read_text(encoding="utf-8")
data = json.loads(raw)

type(data), len(data)
# Out:
# (dict, 10)

# %%
episodes = list(data.keys())
episodes

first_episode = data[episodes[0]]
first_episode

list(first_episode.items())[:5]
# Out:
# [('1', 'Easy, boy.'),
#  ('10', 'Our orders were to track the wildlings.'),
#  ('100', '- Right. Give it here. - No!'),
#  ('101', 'Put away your blade.'),
#  ('102', '- I take orders from your father, not you. - Please, Father!')]

# %%
# !pip install pandas
import pandas as pd

rows = []
for episode_name, subtitles in data.items():
    for subtitle_id, text in subtitles.items():
        rows.append({
            "episode": episode_name,
            "subtitle_id": int(subtitle_id),
            "text": text
        })

df = pd.DataFrame(rows).sort_values(["episode", "subtitle_id"]).reset_index(drop=True)
df.head()
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting pandas
#   Downloading pandas-2.3.3-cp314-cp314-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (91 kB)
# Collecting numpy>=1.26.0 (from pandas)
#   Downloading numpy-2.3.4-cp314-cp314-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (62 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/lib/python3.14/site-packages (from pandas) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas)
#   Downloading pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: tzdata>=2022.7 in /home/user/.local/lib/python3.14/site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3.14/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading pandas-2.3.3-cp314-cp314-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (12.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 44.5 MB/s eta 0:00:00MB/s eta 0:00:01
# Downloading numpy-2.3.4-cp314-cp314-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (16.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.6/16.6 MB 56.9 MB/s eta 0:00:00 MB/s eta 0:00:01
# Downloading pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Installing collected packages: pytz, numpy, pandas
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3/3 [pandas]━━━━━━━━━━━ 2/3 [pandas]
# Successfully installed numpy-2.3.4 pandas-2.3.3 pytz-2025.2
#                                        episode  subtitle_id  \
# 0  Game Of Thrones S01E01 Winter Is Coming.srt            1
# 1  Game Of Thrones S01E01 Winter Is Coming.srt            2
# 2  Game Of Thrones S01E01 Winter Is Coming.srt            3
# 3  Game Of Thrones S01E01 Winter Is Coming.srt            4
# 4  Game Of Thrones S01E01 Winter Is Coming.srt            5
#
#                                                 text
# 0                                         Easy, boy.
# 1               What do you expect? They're savages.
# 2            One lot steals a goat from another lot,
# 3  before you know it they're ripping each other ...
# 4    I've never seen wildlings do a thing like this.

# %%
import re

def clean_episode(name):
    match = re.search(r"S\d+E\d+", name)
    return match.group(0) if match else name

df["episode"] = df["episode"].apply(clean_episode)
df.head()
# Out:
#   episode  subtitle_id                                               text
# 0  S01E01            1                                         Easy, boy.
# 1  S01E01            2               What do you expect? They're savages.
# 2  S01E01            3            One lot steals a goat from another lot,
# 3  S01E01            4  before you know it they're ripping each other ...
# 4  S01E01            5    I've never seen wildlings do a thing like this.

# %%
import re

def tokenize(text):
    return re.findall(r"[A-Za-z']+", text.lower())

df["tokens"] = df["text"].apply(tokenize)
df[["episode", "subtitle_id", "tokens"]].head()
# Out:
#   episode  subtitle_id                                             tokens
# 0  S01E01            1                                        [easy, boy]
# 1  S01E01            2          [what, do, you, expect, they're, savages]
# 2  S01E01            3    [one, lot, steals, a, goat, from, another, lot]
# 3  S01E01            4  [before, you, know, it, they're, ripping, each...
# 4  S01E01            5  [i've, never, seen, wildlings, do, a, thing, l...

# %%
from itertools import chain

all_tokens = list(chain.from_iterable(df["tokens"]))
len(all_tokens)
# Out:
# 44935

# %%
from collections import Counter

freq = Counter(all_tokens)

freq_df = (
    pd.DataFrame(freq.items(), columns=["word", "count"])
    .sort_values("count", ascending=False)
    .reset_index(drop=True)
)

freq_df.head(20)
# Out:
#     word  count
# 0    the   1988
# 1    you   1572
# 2     to   1173
# 3      i   1146
# 4      a   1000
# 5    and    850
# 6     of    743
# 7     my    636
# 8   your    567
# 9     it    495
# 10    is    485
# 11    me    452
# 12    he    403
# 13    in    402
# 14   for    379
# 15  that    358
# 16    be    333
# 17  what    332
# 18    no    325
# 19  have    317

# %%
# !pip install nltk
from nltk.corpus import stopwords
import nltk

nltk.download("stopwords")

stopwords_set = set(stopwords.words("english"))

content_df = (
    freq_df[~freq_df["word"].isin(stopwords_set)]
    .reset_index(drop=True)
)

content_df.head(30)
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: nltk in /home/user/.local/lib/python3.14/site-packages (3.9.2)
# Requirement already satisfied: click in /usr/lib/python3.14/site-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /home/user/.local/lib/python3.14/site-packages (from nltk) (1.5.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/lib64/python3.14/site-packages (from nltk) (2025.10.23)
# Requirement already satisfied: tqdm in /usr/lib/python3.14/site-packages (from nltk) (4.67.1)
# [nltk_data] Downloading package stopwords to /home/user/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
#        word  count
# 0      lord    278
# 1      king    194
# 2      know    176
# 3       one    165
# 4      want    142
# 5       man    138
# 6    father    134
# 7      like    132
# 8     would    132
# 9        go    116
# 10      men    111
# 11      boy    110
# 12       us    106
# 13    stark    102
# 14     come    101
# 15      see    101
# 16     tell    100
# 17     lady     96
# 18     good     95
# 19    never     93
# 20      get     91
# 21  brother     91
# 22     back     84
# 23     time     83
# 24      ser     80
# 25     well     79
# 26     take     78
# 27   little     78
# 28      say     77
# 29       oh     76

# %%
# !pip install matplotlib
import matplotlib.pyplot as plt

top_n = 20
subset = content_df.head(top_n)

plt.figure(figsize=(10,6))
plt.bar(range(top_n), subset["count"])
plt.xticks(range(top_n), subset["word"], rotation=90)
plt.ylabel("Count")
plt.title("Top 20 words (NLTK stopword filtering)")
plt.tight_layout()
plt.show()
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting matplotlib
#   Downloading matplotlib-3.10.7-cp314-cp314-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (11 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.3.3-cp314-cp314-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.60.1-cp314-cp314-manylinux1_x86_64.manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_5_x86_64.whl.metadata (112 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.4.9-cp314-cp314-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (6.3 kB)
# Requirement already satisfied: numpy>=1.23 in /home/user/.local/lib/python3.14/site-packages (from matplotlib) (2.3.4)
# Requirement already satisfied: packaging>=20.0 in /usr/lib/python3.14/site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/lib64/python3.14/site-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=3 in /usr/lib/python3.14/site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/lib/python3.14/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3.14/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Downloading matplotlib-3.10.7-cp314-cp314-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (9.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.8/9.8 MB 38.9 MB/s eta 0:00:0031m38.5 MB/s eta 0:00:01
# Downloading contourpy-1.3.3-cp314-cp314-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (363 kB)
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.60.1-cp314-cp314-manylinux1_x86_64.manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_5_x86_64.whl (4.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/4.8 MB 65.1 MB/s eta 0:00:00
# Downloading kiwisolver-1.4.9-cp314-cp314-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 26.4 MB/s eta 0:00:00
# Installing collected packages: kiwisolver, fonttools, cycler, contourpy, matplotlib
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5/5 [matplotlib] 4/5 [matplotlib]
# Successfully installed contourpy-1.3.3 cycler-0.12.1 fonttools-4.60.1 kiwisolver-1.4.9 matplotlib-3.10.7

# %%
keywords = ["lord", "king", "stark", "father", "ser"]

rows = []
for ep, group in df.groupby("episode"):
    tokens = list(chain.from_iterable(group["tokens"]))
    counts = Counter(tokens)
    for word in keywords:
        rows.append({
            "episode": ep,
            "word": word,
            "count": counts[word]
        })

ep_df = pd.DataFrame(rows)
ep_df
# Out:
#    episode    word  count
# 0   S01E01    lord     14
# 1   S01E01    king     22
# 2   S01E01   stark      9
# 3   S01E01  father     14
# 4   S01E01     ser      3
# 5   S01E02    lord     12
# 6   S01E02    king      9
# 7   S01E02   stark      9
# 8   S01E02  father      3
# 9   S01E02     ser      4
# 10  S01E03    lord     29
# 11  S01E03    king     18
# 12  S01E03   stark     16
# 13  S01E03  father     13
# 14  S01E03     ser      3
# 15  S01E04    lord     49
# 16  S01E04    king     10
# 17  S01E04   stark     13
# 18  S01E04  father     15
# 19  S01E04     ser     16
# 20  S01E05    lord     37
# 21  S01E05    king     33
# 22  S01E05   stark     15
# 23  S01E05  father     18
# 24  S01E05     ser     16
# 25  S01E06    lord     17
# 26  S01E06    king     17
# 27  S01E06   stark      3
# 28  S01E06  father      7
# 29  S01E06     ser      8
# 30  S01E07    lord     43
# 31  S01E07    king     20
# 32  S01E07   stark     13
# 33  S01E07  father      8
# 34  S01E07     ser     10
# 35  S01E08    lord     44
# 36  S01E08    king     17
# 37  S01E08   stark      8
# 38  S01E08  father     26
# 39  S01E08     ser      9
# 40  S01E09    lord     25
# 41  S01E09    king      8
# 42  S01E09   stark      9
# 43  S01E09  father     20
# 44  S01E09     ser      4
# 45  S01E10    lord      8
# 46  S01E10    king     40
# 47  S01E10   stark      7
# 48  S01E10  father     10
# 49  S01E10     ser      7

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,6))

for word in keywords:
    subset = ep_df[ep_df["word"] == word]
    plt.plot(subset["episode"], subset["count"], marker="o", label=word)

plt.xlabel("Episode")
plt.ylabel("Count")
plt.title("Keyword frequency per episode")
plt.legend()
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
